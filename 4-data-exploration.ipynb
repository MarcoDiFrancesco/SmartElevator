# %% [markdown]
# # Data exploration

# %%
import json
import pandas as pd
from utils import import_df
import seaborn as sns
import matplotlib.pyplot as plt

df = import_df("3-noise-generation-output.json")
df_base = df.copy()
df.head()
# Out:
#        s_00      s_01       s_02      s_03      s_04      s_05      s_06  \
# 0 -0.265235 -5.048122  -3.631346 -4.439543 -3.357498 -0.204776 -1.318228
# 1  1.803906 -7.633756  -5.389268 -1.570934 -2.791938 -1.642577 -1.893539
# 2  0.034944 -7.383289 -10.814815 -5.313512 -2.078825 -0.999530 -2.935479
# 3 -1.236713 -6.816264  -4.414403 -2.289054 -2.182520 -1.306811 -1.128795
# 4 -0.631867  1.805891  -4.057512 -3.777951 -4.524474 -0.794026 -2.293586
#
#        s_07      s_08      s_09  ...  vib_y_f3  vib_y_kurt  vib_y_peak  \
# 0 -0.339534 -1.400015 -0.246901  ...  2.714593    0.492976    0.603847
# 1  0.155088 -0.426586  0.362725  ...  0.236706    0.724190    0.840423
# 2 -0.510686 -0.604878 -0.327708  ...  0.659316    0.623644    0.659468
# 3  0.227098  0.474560 -0.287856  ... -0.075597    0.661056    0.600652
# 4  0.294561 -0.637668 -0.196524  ...  2.600142    0.601755    0.647312
#
#    vib_y_vel  vib_z_acc  vib_z_kurt  vib_z_peak  vib_z_vel   current  \
# 0   2.324498   1.467088    0.164199    0.817187   2.849615  3.974052
# 1   2.849037   1.844653   -0.383697    0.384010   0.855245  3.966374
# 2   1.542131   1.696922    0.437205    0.764138   2.917843  3.971816
# 3   2.515246   1.543970    0.487229    0.668764   2.192881  3.963132
# 4   2.270040   1.837363    0.157348    0.354827   1.877270  3.961272
#
#               label
# 0  working-engine-1
# 1  working-engine-1
# 2  working-engine-1
# 3  working-engine-1
# 4  working-engine-1
#
# [5 rows x 39 columns]

# %%
df_corr = df.corr()
df_corr.head()
# Out:
#           s_00      s_01      s_02      s_03      s_04      s_05      s_06  \
# s_00  1.000000 -0.244611 -0.137015 -0.121582 -0.112571 -0.098316 -0.097707
# s_01 -0.244611  1.000000  0.386625  0.390629  0.365333  0.290784  0.299029
# s_02 -0.137015  0.386625  1.000000  0.450441  0.410873  0.329836  0.344279
# s_03 -0.121582  0.390629  0.450441  1.000000  0.412021  0.327256  0.343655
# s_04 -0.112571  0.365333  0.410873  0.412021  1.000000  0.298142  0.318056
#
#           s_07      s_08      s_09  ...  vib_y_f2  vib_y_f3  vib_y_kurt  \
# s_00 -0.018459 -0.004184 -0.019975  ...  0.097540  0.101598   -0.152619
# s_01 -0.034613 -0.021402 -0.019568  ... -0.073800 -0.075719    0.409248
# s_02 -0.022210 -0.030136 -0.017532  ... -0.032289 -0.020720    0.450578
# s_03 -0.035183 -0.028517 -0.016274  ... -0.058952 -0.048120    0.458203
# s_04 -0.048393 -0.021493 -0.020204  ... -0.055073 -0.047133    0.421402
#
#       vib_y_peak  vib_y_vel  vib_z_acc  vib_z_kurt  vib_z_peak  vib_z_vel  \
# s_00    0.141517   0.341973   0.016225   -0.119800   -0.220780  -0.070491
# s_01    0.241747  -0.407801  -0.342594    0.424692    0.366875  -0.137192
# s_02    0.321670  -0.403034  -0.466455    0.472556    0.307099  -0.329221
# s_03    0.331055  -0.360158  -0.427792    0.470024    0.357242  -0.231390
# s_04    0.302924  -0.335743  -0.395830    0.434278    0.329049  -0.211400
#
#        current
# s_00  0.230186
# s_01 -0.041747
# s_02 -0.085888
# s_03 -0.050521
# s_04 -0.037114
#
# [5 rows x 38 columns]

# %%
fig, heat = plt.subplots(figsize = (25,25))
sns.heatmap(df_corr, xticklabels=df_corr.columns, yticklabels=df_corr.columns, annot=True, fmt= ',.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Pair plot

# %%
# sns.heatmap(df_corr, xticklabels=df_corr.columns, yticklabels=df_corr.columns, annot=True, fmt= ',.2f')
print(df.columns)
dff = df.filter(
    [
        # 's_00', 's_01', 's_02', 's_03', 's_04', 's_05', 's_06', 's_07', 's_08',
        # 's_09', 's_10',
        's_11', 's_12', 's_13', 's_14', 
        # 's_15', 's_16', 's_17',
        # 's_18', 's_19',
        # 'sonic_custom',
        #'sonic_rmslog', 'vib_x_acc',
        # 'vib_x_kurt', 'vib_x_peak', 'vib_x_vel',
        #'vib_y_acc',
        #'vib_y_f1',
        # 'vib_y_f2', 'vib_y_f3', 'vib_y_kurt', 'vib_y_peak', 'vib_y_vel',
        # 'vib_z_acc', 'vib_z_kurt', 'vib_z_peak', 'vib_z_vel', 'current',
        'label',
    ]
)
sns.pairplot(dff, hue="label", kind='kde')
# Out:
# Index(['s_00', 's_01', 's_02', 's_03', 's_04', 's_05', 's_06', 's_07', 's_08',
#        's_09', 's_10', 's_11', 's_12', 's_13', 's_14', 's_15', 's_16', 's_17',
#        's_18', 's_19', 'sonic_custom', 'sonic_rmslog', 'vib_x_acc',
#        'vib_x_kurt', 'vib_x_peak', 'vib_x_vel', 'vib_y_acc', 'vib_y_f1',
#        'vib_y_f2', 'vib_y_f3', 'vib_y_kurt', 'vib_y_peak', 'vib_y_vel',
#        'vib_z_acc', 'vib_z_kurt', 'vib_z_peak', 'vib_z_vel', 'current',
#        'label'],
#       dtype='object')
